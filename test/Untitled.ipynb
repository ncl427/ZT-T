# %%
#  Copyright (c) 2022.  NetFoundry, Inc.
#
#  Licensed under the Apache License, Version 2.0 (the "License");
#  you may not use this file except in compliance with the License.
#  You may obtain a copy of the License at
#
#  https://www.apache.org/licenses/LICENSE-2.0
#
#  Unless required by applicable law or agreed to in writing, software
#  distributed under the License is distributed on an "AS IS" BASIS,
#  WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#  See the License for the specific language governing permissions and
#  limitations under the License.

import openziti
import requests

if __name__ == '__main__':
    with openziti.monkeypatch():
        r = requests.get('http://httpbin.ziti/')
        print(r.headers)
        print(r.json())
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\openziti\zitisock.py in connect(self, addr)
#      47             try:
# ---> 48                 zitilib.connect_addr(self._zitifd, addr)
#      49             except:
#
# ~\anaconda3\lib\site-packages\openziti\zitilib.py in connect_addr(fd, addr)
#     144     port = addr[1]
# --> 145     check_error(_ziti_connect_addr(fd, host, port))
#     146
#
# ~\anaconda3\lib\site-packages\openziti\zitilib.py in check_error(code)
#     118             msg = errorstr(err)
# --> 119         raise Exception(err, msg)
#     120
#
# Exception: (107, 'unexpected error')
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# ...

# %%
import sys

import urllib3
import openziti
import os
from os import getenv

from config.definitions import ROOT_DIR



# to run this sample
# set ZITI_IDENTITIES environment variable to location of your Ziti identity file
#
# python http-get.py <url>
# url should be the intercept address of a ziti service
idFolder =  os.path.join(ROOT_DIR, 'identity')

os.environ["ZITI_IDENTITIES"] = "ZTClient/test/myId.json"
print(getenv('ZITI_IDENTITIES'))

if __name__ == '__main__':
    openziti.monkeypatch()
    http = urllib3.PoolManager()
    r = http.request('GET', "http://golanghttp:1234/")
    print("{0} {1}".format(r.status, r.reason))
    print(r.data.decode('utf-8'))
# Out:
# ZTClient/test/myId.json
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\openziti\zitisock.py in connect(self, addr)
#      47             try:
# ---> 48                 zitilib.connect_addr(self._zitifd, addr)
#      49             except:
#
# ~\anaconda3\lib\site-packages\openziti\zitilib.py in connect_addr(fd, addr)
#     144     port = addr[1]
# --> 145     check_error(_ziti_connect_addr(fd, host, port))
#     146
#
# ~\anaconda3\lib\site-packages\openziti\zitilib.py in check_error(code)
#     118             msg = errorstr(err)
# --> 119         raise Exception(err, msg)
#     120
#
# Exception: (107, 'unexpected error')
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
# ...
